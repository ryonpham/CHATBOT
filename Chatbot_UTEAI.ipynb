# %% [markdown]
# <a href="https://colab.research.google.com/github/ryonpham/CHATBOT/blob/main/Chatbot_UTEAI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
pip install nltk
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

url='/content/chuan2022.csv'
data2022 = pd.read_csv(url)
data2022.head(4)
# Out:
#     Ma nganh            Ten nganh          To hop mon  Diem chuan  \
# 0  71440231D    Su pham Tieng Anh            D01; D96       26.08
# 1   7210403D      Thiet ke do hoa  V01; V02; V07; V08       24.50
# 2   7210404C  Thiet ke thoi trang  V01; V02; V07; V09       21.60
# 3   7210404D  Thiet ke thoi trang  V01; V02; V07; V09       21.60
#
#              Ghi chu
# 0         He Dai Tra
# 1         He Dai Tra
# 2  He CLC tieng Viet
# 3         He Dai Tra

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

url1='/content/chuan2021(1).csv'
data2021 = pd.read_csv(url1)
data2021.head(4)
# Out:
#    Ma nganh            Ten nganh     To hop mon  Diem chuan  \
# 0  7140231D    Su pham Tieng Anh       D01; D96       27.25
# 1  7210403D      Thiet ke do hoa       V01; V07       24.25
# 2  7210403D      Thiet ke do hoa       V02; V08       24.75
# 3  7210404C  Thiet ke thoi trang  V01; V07; V09       21.25
#
#                         Ghi chu
# 0                    He dai tra
# 1                    He dai tra
# 2                    He dai tra
# 3  He Chat luong cao tieng Viet

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

url2='/content/chuan2020(1).csv'
data2020 = pd.read_csv(url2)
data2020.head(4)
# Out:
#    Ma nganh            Ten nganh          To hop mon  Diem chuan     Ghi chu
# 0  7140231D    Su pham tieng Anh            D01, D96       25.50  He dai tra
# 1  7210403D      Thiet ke do hoa  V01, V02, V07, V08       23.75  He dai tra
# 2  7210404D  Thiet ke thoi trang  V01, V02, V07, V09       22.00  He dai tra
# 3  7220201D         Ngon ngu Anh            D01, D96       24.00  He dai tra

# %%
score_distribution = df.groupby(['Ten nganh', 'Diem chuan']).size().reset_index(name='Count')
print(score_distribution)
# Out:
#                                    Ten nganh  Diem chuan  Count
# 0                          An toan thung tin       26.00      1
# 1    Cong nghe Thong tin (TongmyongHan Quoc)       16.00      1
# 2                      Cong nghe che tao May       19.05      2
# 3                      Cong nghe che tao May       21.30      1
# 4                      Cong nghe che tao May       23.00      1
# ..                                       ...         ...    ...
# 322                      cong nghe thuc pham       26.00      1
# 323                      cong nghe thuc pham       26.50      1
# 324                       cong nghe vat lieu       23.75      1
# 325                       cong nghe vat lieu       24.25      1
# 326   tai chinh ngan hang (Sunderland - Anh)       16.00      1
#
# [327 rows x 3 columns]

# %%
from sklearn.linear_model import LinearRegression
from sklearn.feature_extraction.text import CountVectorizer
import pandas as pd

url='/content/chuan2022.csv'
data2022 = pd.read_csv(url)
data2022.head(4)
url1='/content/chuan2021(1).csv'
data2021 = pd.read_csv(url1)
data2021.head(4)
url2='/content/chuan2020(1).csv'
data2020 = pd.read_csv(url2)
data2020.head(4) 

# Dữ liệu năm 2022
df_2022 = pd.DataFrame(data2022)
# Dữ liệu năm 2021
df_2021 = pd.DataFrame(data2021)
# Dữ liệu năm 2020
df_2020 = pd.DataFrame(data2020)

# Kết hợp dữ liệu từ 3 năm 2020, 2021, 2022
df = pd.concat([df_2020, df_2021, df_2022], ignore_index=True)

# Mã hóa cột 'Ten nganh' thành các vector đặc trưng
vectorizer = CountVectorizer()
X = vectorizer.fit_transform(df['Ten nganh']).toarray()

# Xây dựng mô hình Linear Regression
model = LinearRegression()

# Huấn luyện mô hình trên dữ liệu đã được mã hóa
model.fit(X, df['Diem chuan'])

# Dự đoán điểm chuẩn cho năm 2023
data2023 = {
    'Ma nganh': ['71440231D', '7210403D', '7210404C', '7210404D', '7220201D', '7340120D', '7340122C', '7340122D', '7340301C', '7340301D', '7480108A'],
    'Ten nganh': ['Su pham Tieng Anh', 'Thiet ke do hoa', 'Thiet ke thoi trang', 'Ngon ngu Anh', 'Kinh doanh quoc te', 'Thuong mai dien tu', 'Ke toan', 'Cong nghe ky thuat May tinh']
}

# %%
import nltk
from nltk.tokenize import word_tokenize, WhitespaceTokenizer
import random
from datetime import date, datetime
import numpy as np 

# Đường dẫn đến file stopwords.vi
url0 = '/content/drive/MyDrive/Colab Notebooks/stopwords_vi.vi'
# Đọc dữ liệu từ file stopwords.vi
dataframe = pd.read_csv(url0, sep='\t', header=None, names=['Stopword'])
# Chuyển đổi dữ liệu thành list stopwords
stopwords_vi = dataframe['Stopword'].tolist()


def ai():
    print("Chào mừng bạn đến với Chatbot HCMUTE! Tôi là UTEAI.")
    print("Hãy hỏi tôi bất cứ điều gì về Trường Đại học Sư phạm Kỹ thuật Thành phố Hồ Chí Minh.")
        
    greet = ["Chào bạn", "Xin chào", "Hello", "Hi", "Chào cậu", "Hello bạn", "Chào"]
    help = ["làm", "giúp", "hỗ trợ", "giúp bạn", "làm được", "giúp được", "hỗ trợ được", "giúp bạn với vấn đề"]
    hnay = ["hôm nay", "nay", "ngày hôm nay"]
    bgio = ["giờ", "bây giờ", "đang"]
    bye = ["Tạm biệt", "Chào tạm biệt", "Chào", "Bye", "Goodbye"]
    yn = [" nhỉ", " không", " không nhỉ", " nào", ""]
    skai = ["là một trí tuệ nhân tạo", "là một AI hay một trí tuệ nhân tạo - Artificial Inteligence", "không có cơ thể sinh học", "không có cơ thể", "chỉ tồn tại ở dạng phần mềm"]
    feelai = [" nên không có cảm giác", " nên không cảm thấy gì cả", " nên không cảm thấy gì", " nên mình không thể cảm thấy gì", " nên mình không có cảm giác gì", " nên mình không biết nữa", " nên mình không biết", " nên mình cũng không biết nữa", " nên mình cũng không biết"]
    khoeko = ["sức khỏe", " "]
    andyou = ["còn ", ""]
    ugud = [" thì sao", " ổn không", " tốt không", ""]
    sr = ["Xin lỗi", "Rất tiếc", "Đáng tiếc", "Thật đáng tiếc", "Mình rất xin lỗi", "Mình rất tiếc"]
    it = ["mình ", ""]
    noans = ["có câu trả lời cho điều này", "được học điều này", "biết thông tin gì về điều này", "trả lời được điều này", "thể trả lời được điều này", "thể trả lời được câu này", "giải đáp được điều này", "thể giải đáp được điều này", "thể cung cấp bất kì thông tin nào về việc này", "thể cung cấp bất kì thông tin nào về điều này"]
    bonus = ["Bạn có thể đổi câu hỏi khác.", "Bạn có muốn đổi câu hỏi?", "Mình có thể giúp bạn với câu hỏi khác không?", "Bạn hãy hỏi mình câu khác nhé.", "Nếu cần giúp gì nữa thì cứ nói mình nhé.", "Mình có thể sẽ giúp được bạn với câu hỏi khác chi tiết hơn đấy.", "Bạn có câu hỏi chi tiết hơn không?", "Nếu như bạn chi tiết hơn thì có thể mình sẽ giúp bạn được đấy."]
    
    address = ["1 Võ Văn Ngân, Phường Linh Chiểu, Thành phố Thủ Đức, Thành phố Hồ Chí Minh."]
    sdt = ["(+84 - 028) 38968641 - (+84 -028) 38961333 - (+84 -028) 37221223"]
    Hotline = ["(+84 - 028) 37222764"]
    Fax = ["(+84 - 028) 38964922"]
    mail = ["ptchc@hcmute.edu.vn"]

    chuongtrinh = ["HCMUTE cung cấp một loạt các chương trình đào tạo bao gồm kỹ thuật, khoa học máy tính, kinh doanh và nhiều hơn nữa.", "Chương trình đào tạo tại HCMUTE đa dạng, bao gồm kỹ thuật, khoa học máy tính, kinh doanh và nhiều lĩnh vực khác.", "HCMUTE có nhiều chương trình đào tạo phù hợp với các ngành nghề và sở thích của sinh viên."]
    admissions = ["Để được nhập học vào HCMUTE, bạn cần tuân theo quy trình tuyển sinh của trường. Bạn có thể truy cập trang web chính thức để biết thông tin chi tiết.", "Thông tin về quy trình tuyển sinh vào HCMUTE có thể được tìm thấy trên trang web chính thức của trường.", "Hãy xem thông tin tuyển sinh trên trang web của HCMUTE để biết cách nộp hồ sơ và các yêu cầu khác."]
    facilities = ["HCMUTE có các cơ sở vật chất hiện đại, bao gồm các phòng học tiên tiến, phòng thí nghiệm được trang bị đầy đủ, thư viện và cơ sở thể thao.", "Trường Đại học Sư phạm Kỹ thuật Thành phố Hồ Chí Minh có các cơ sở vật chất đáp ứng tốt nhu cầu học tập và nghiên cứu của sinh viên.","HCMUTE đầu tư vào cơ sở vật chất để tạo điều kiện tốt nhất cho sinh viên trong quá trình học tập và nghiên cứu."]
    location = ["HCMUTE nằm tại thành phố Hồ Chí Minh, Việt Nam.", "Trường Đại học Sư phạm Kỹ thuật Thành phố Hồ Chí Minh có địa điểm tại thành phố Hồ Chí Minh.", "Vị trí của HCMUTE là ở thành phố Hồ Chí Minh, một thành phố sôi động và phát triển ở Việt Nam."]
    contact = ["Bạn có thể liên hệ với HCMUTE qua số điện thoại +84 28 3896 2015 hoặc truy cập trang web chính thức để biết thông tin liên hệ khác.", "Nếu bạn muốn liên hệ với HCMUTE, bạn có thể gọi đến số điện thoại +84 28 3896 2015 hoặc tham khảo trang web chính thức của trường.", "Thông tin liên hệ với HCMUTE có sẵn trên trang web chính thức hoặc bạn có thể gọi đến số điện thoại +84 28 3896 2015 để được hỗ trợ."]
    history = ["HCMUTE được thành lập vào năm 1962 và có một lịch sử phong phú trong việc cung cấp giáo dục chất lượng trong lĩnh vực công nghệ và kỹ thuật.", "Trường Đại học Sư phạm Kỹ thuật Thành phố Hồ Chí Minh có một lịch sử lâu đời và đóng góp đáng kể vào việc đào tạo nhân tài trong lĩnh vực công nghệ.", "Lịch sử của HCMUTE bắt đầu từ năm 1962 và đã trải qua nhiều giai đoạn phát triển để trở thành một trong những trường đại học hàng đầu về công nghệ và kỹ thuật."]
    faculty = ["HCMUTE có một đội ngũ giảng viên rất có trình độ với các chuyên gia trong các lĩnh vực khác nhau, cam kết truyền đạt kiến thức và thúc đẩy nghiên cứu.", "Đội ngũ giảng viên của HCMUTE bao gồm những người có kinh nghiệm và trình độ cao, giúp sinh viên nắm vững kiến thức và phát triển kỹ năng.", "Giảng viên tại HCMUTE là những chuyên gia hàng đầu trong lĩnh vực của mình, sẵn sàng hỗ trợ sinh viên trong quá trình học tập và nghiên cứu."]
    research = ["HCMUTE đang tích cực tham gia vào nghiên cứu trong các lĩnh vực như năng lượng bền vững, trí tuệ nhân tạo và sản xuất tiên tiến.", "Nghiên cứu là một hoạt động quan trọng tại HCMUTE và trường đang tập trung vào các lĩnh vực năng lượng bền vững, trí tuệ nhân tạo và sản xuất tiên tiến.", "HCMUTE đưa nghiên cứu và sáng tạo vào tâm điểm, thúc đẩy các hoạt động nghiên cứu về năng lượng bền vững, trí tuệ nhân tạo và sản xuất tiên tiến."]

    tk = WhitespaceTokenizer()
    name = "Bạn"  # Tên mặc định cho người dùng  
    while True:
        you = input("Bạn: ")
        tokens = tk.tokenize(you.lower())
       
        # tokens = word_tokenize(you, "vi")
        filtered_tokens = [word for word in tokens if word.casefold() not in stopwords_vi]
        print(filtered_tokens)
        
        if ("xin chào" in filtered_tokens) or (("chào" in filtered_tokens) and ("bạn" in filtered_tokens)) or ("hello" in filtered_tokens) or ("helu" in filtered_tokens) or ("chào" in filtered_tokens):
            uteai = random.choice(greet) + ", mình có thể " + random.choice(help) + " gì" + random.choice(yn) + "?"   
            
        elif any(word.lower() in filtered_tokens for word in ["tên", "tôi", "mình", "tớ", "tui", "t"]):
            name = ""  # Initialize name with a default value
            for word in filtered_tokens:
                
                # if (word in ["tên", "tôi", "mình"]):
                #     keyword_index = filtered_tokens.index(word)
                #     if keyword_index < len(filtered_tokens) - 1:
                #         following_word = filtered_tokens[keyword_index + 1]
                #         if following_word:
                #             name = following_word.title()
                #             break
                
                if (word not in ["tên", "tôi", "mình", "tớ", "tui", "t"]):
                    keyword_index = filtered_tokens.index(word)
                    following_word = filtered_tokens[keyword_index]
                    if following_word:
                        name = following_word.title()
                        break
                    
            if name:
                uteai = random.choice(greet) + " " + name + ", mình có thể " + random.choice(help) + " gì" + random.choice(yn) + "?"
            else:
                uteai = random.choice(greet) + ", mình có thể " + random.choice(help) + " gì" + random.choice(yn) + "?"

        elif (("khỏe" in filtered_tokens) and (("không" or "ko)" in filtered_tokens))):
            uteai = "Mình " + random.choice(skai) + random.choice(feelai) + "," + random.choice(andyou) + random.choice(khoeko) + ("bạn" or name) + random.choice (ugud) + "?"
       
        elif "nay" in filtered_tokens and "ngày" in filtered_tokens:
            nay = date.today()
            uteai = random.choice(hnay) + " là " + nay.strftime("%d/%m/%Y")
            
        elif (("giờ" in filtered_tokens) and ("đang" in filtered_tokens)) or (("mấy" in filtered_tokens) and ("giờ" in filtered_tokens)):
            gio = datetime.now()
            uteai = random.choice(bgio) + " là " + gio.strftime("%H:%M:%S")
        
        elif (("địa" in filtered_tokens and "chỉ" in filtered_tokens) or ("trường" in filtered_tokens and "nằm" in filtered_tokens) or ("trường" in filtered_tokens and "ở" in filtered_tokens) or ("trường" in filtered_tokens and "đâu" in filtered_tokens)):
            uteai = address
        elif (("số" in filtered_tokens and "điện" in filtered_tokens and "thoại" in filtered_tokens) or ("sđt" in filtered_tokens) or ("liên" in filtered_tokens and "hệ" in filtered_tokens) or ("sdt" in filtered_tokens)):
            uteai = "Đây là số điện thoại của từ các văn phòng tại HCMUTE: " + sdt
        elif "hotline" in filtered_tokens:
            uteai = "Địa chỉ hotline của HCMUTE: " + Hotline
        elif "fax" in filtered_tokens or "địa chỉ fax" in filtered_tokens:
            uteai = "Địa chỉ fax của HCMUTE: " + Fax
        elif "email" in filtered_tokens or "mail" in filtered_tokens:
            uteai = "Địa chỉ email của văn phòng HCMUTE là: " + mail
        elif "liên" in filtered_tokens and "lạc" in filtered_tokens:
            uteai = "Hãy liên lạc theo địa chỉ sau nhé: " + random.choice(sdt + Hotline + Fax + mail)

        elif "chương trình" in filtered_tokens:
            uteai = random.choice(chuongtrinh)
        elif "tuyển sinh" in filtered_tokens:
            uteai = random.choice(admissions)
        elif "cơ sở vật chất" in filtered_tokens:
            uteai = random.choice(facilities)
        elif "lịch sử" in filtered_tokens:
            uteai = random.choice(history)
        elif "giảng viên" in filtered_tokens:
            uteai = random.choice(faculty)
        elif "nghiên cứu" in filtered_tokens:
            uteai = random.choice(research)

        elif ("tạm biệt" in filtered_tokens) or ("chào" in filtered_tokens and "tạm biệt" in filtered_tokens) or ("bye" in filtered_tokens):
            uteai = random.choice(bye)+ " bạn và hẹn gặp lại nhé!"
            print("UTEAI: " + uteai)
            break
        else:
            uteai = random.choice(sr) + " vì " + random.choice(it) + "chưa " + random.choice(noans) + ". " + random.choice(bonus)
        print("UTEAI: " + uteai)

ai()
# Out:
# Chào mừng bạn đến với Chatbot HCMUTE! Tôi là UTEAI.
# Hãy hỏi tôi bất cứ điều gì về Trường Đại học Sư phạm Kỹ thuật Thành phố Hồ Chí Minh.
# Bạn: bye
# ['bye']
# UTEAI: Bye bạn và hẹn gặp lại nhé!
